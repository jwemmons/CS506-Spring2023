# %% [markdown]
# ## Lab 02 - Pandas and Data Visualization - 07 February, 2023
# This notebook will introduce you to the basics of Pandas and Data Visualization. You will learn how to load data into a Pandas DataFrame, how to perform basic data analysis, and how to visualize data. The first part of this notebook will be an interactive tutorial, and the second part will be practice exercises for you to do! Note that the practice problems will be checked when submitted!

# %% [markdown]
# ### Pre-requisites

# %%
# In case you don't have pandas, uncomment
# the following lines and run the cell

# %pip install pandas

# %% [markdown]
# ### Overview
# In this notebook, you will be learning how to use the Pandas library by working with the `cookies.csv` file.
#
# #### `cookies.csv` file
#
# The `cookies.csv` file contains information about cookies that were made from a single Rico's Bisquito's factory. There are, however, a few differences from the classes defined in homework0.
#
# Here, this dataset shows all the cookies made from a single factory, where now the `cost_to_make` may not be the same for a single cookie because someone may have, for example, added too much flour.
#
# The columns are the following:
#
# `cookie`: the name of a cookie
# `ingredients`: a list of the cookie's ingredients
# `calories`: the number of calories the created cookie has
# `radius`: the radius of the created cookie, in cm
# `cost_to_make`: the cost it took to make the created cookie, in dollars

# %% [markdown]
# ### Reading the CSV file
#
# First, we need to import the Pandas library. We will be using the `pd` alias for the Pandas library.

# %%
#TODO: import pandas and matplotlib in this cell
import pandas as pd
import matplotlib

# %% [markdown]
# We will now look at the `cookies.csv` file. We will use the `pd.read_csv()` function to read in the CSV file. We will store the data in a variable called `cookies`.

# %%
#TODO: read the cookies.csv file into a pandas dataframe
cookies = pd.read_csv("cookies.csv")

# %% [markdown]
# What is the DataFrame used? Well, Dataframes are a data structure that Pandas uses to store data. Dataframes are similar to tables in a database. Dataframes have rows and columns. Each row represents a single data point, and each column represents a feature of the data point.

# %% [markdown]
# We will then make sure we imported the data correctly by printing out the first 10 rows of the data, using the `head()` function.

# %%
#TODO: print the head of the dataframe
cookies.head(50)
# Out:
#              cookie                                        ingredients  \
# 0      laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 1          nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 2   red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 3   bad berry bunny           ["flour","blueberries","sugar","butter"]
# 4      orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 5       minty miami          ["flour","mint extract","sugar","butter"]
# 6         chocolate       ["flour","chocolate chips","sugar","butter"]
# 7      laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 8          nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 9   red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 10  bad berry bunny           ["flour","blueberries","sugar","butter"]
# 11     orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 12      minty miami          ["flour","mint extract","sugar","butter"]
# 13        chocolate       ["flour","chocolate chips","sugar","butter"]
# 14     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 15         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 16  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 17  bad berry bunny           ["flour","blueberries","sugar","butter"]
# 18     orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 19      minty miami          ["flour","mint extract","sugar","butter"]
# 20        chocolate       ["flour","chocolate chips","sugar","butter"]
# 21     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 22         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 23  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 24     orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 25      minty miami          ["flour","mint extract","sugar","butter"]
# 26        chocolate       ["flour","chocolate chips","sugar","butter"]
# 27     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 28         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 29  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 30  bad berry bunny           ["flour","blueberries","sugar","butter"]
# 31     orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 32      minty miami          ["flour","mint extract","sugar","butter"]
# 33        chocolate       ["flour","chocolate chips","sugar","butter"]
# 34     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 35         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 36  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 37  bad berry bunny           ["flour","blueberries","sugar","butter"]
# 38     orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 39      minty miami          ["flour","mint extract","sugar","butter"]
# 40        chocolate       ["flour","chocolate chips","sugar","butter"]
# 41     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 42         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 43  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 44  bad berry bunny           ["flour","blueberries","sugar","butter"]
# 45     orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 46      minty miami          ["flour","mint extract","sugar","butter"]
# 47        chocolate       ["flour","chocolate chips","sugar","butter"]
# 48     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 49         nevadito  ["flour","chocolate chips","milk","vanilla ext...
#
#     calories  radius  cost_to_make
# 0        170   3.102          0.67
# 1        224   4.069          1.04
# 2        198   3.780          1.07
# 3        191   4.148          1.39
# 4        162   3.241          1.15
# 5        204   3.964          0.84
# 6        243   3.684          1.17
# 7        178   3.989           NaN
# 8        216   3.848          1.28
# 9        211   3.940          0.76
# 10       183   3.874          1.07
# 11       159   3.429          2.09
# 12       175   3.766          0.77
# 13       209   3.182          1.53
# 14       167   3.548          1.86
# 15       236   4.043          1.29
# 16       202   4.289          1.23
# 17       184   2.982          2.01
# 18       156   3.765          1.63
# 19       184   3.343           NaN
# 20       205   3.383           NaN
# 21       176   3.809           NaN
# 22       219   4.346          1.18
# 23       204   4.667          1.40
# 24       198   3.448          0.68
# 25       178   2.952          0.84
# 26       205   3.937           NaN
# 27       187   3.257          0.69
# 28       211   4.152          1.72
# 29       193   3.172          0.97
# 30       182   4.166          1.11
# 31       162   3.498          1.18
# 32       183   3.946          1.05
# 33       206   3.681           NaN
# 34       176   4.110          2.27
# 35       205   3.776          0.96
# 36       203   4.272          1.94
# 37       213   4.007          1.34
# 38       183   3.627          1.41
# 39       174   4.388          0.64
# 40       240   4.212          0.97
# 41       195   4.562          0.62
# 42       220   3.855          2.21
# 43       193   3.661          1.59
# 44       184   3.974          0.77
# 45       159   3.462          1.01
# 46       205   4.218          0.75
# 47       229   4.217          1.19
# 48       165   4.123          2.00
# 49       208   3.583          1.42

# %% [markdown]
# ### Checking data types
# You can check the data types of each column using the `dtypes` attribute of the DataFrame.

# %%
#TODO: check the data types of the columns
cookies.dtypes
# Out:
# cookie           object
# ingredients      object
# calories          int64
# radius          float64
# cost_to_make    float64
# dtype: object

# %% [markdown]
# ### Cleaning the data
# Now that we have the data, we need to clean it. For example, some `cost_to_make` fields of some created cookies are missing. To resolve this, we can do many things: we can replace the missing data with the mean of the column, or we can get rid of the row entirely if the `cost_to_make` field is not set.

# %%
#TODO: clean the dataframe and 
# print the head again to make sure 
# the changes took effect
cookies = cookies[cookies["cost_to_make"].notnull()]
cookies.head(50)
# Out:
#              cookie                                        ingredients  \
# 0      laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 1          nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 2   red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 3   bad berry bunny           ["flour","blueberries","sugar","butter"]
# 4      orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 5       minty miami          ["flour","mint extract","sugar","butter"]
# 6         chocolate       ["flour","chocolate chips","sugar","butter"]
# 8          nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 9   red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 10  bad berry bunny           ["flour","blueberries","sugar","butter"]
# 11     orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 12      minty miami          ["flour","mint extract","sugar","butter"]
# 13        chocolate       ["flour","chocolate chips","sugar","butter"]
# 14     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 15         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 16  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 17  bad berry bunny           ["flour","blueberries","sugar","butter"]
# 18     orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 22         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 23  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 24     orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 25      minty miami          ["flour","mint extract","sugar","butter"]
# 27     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 28         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 29  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 30  bad berry bunny           ["flour","blueberries","sugar","butter"]
# 31     orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 32      minty miami          ["flour","mint extract","sugar","butter"]
# 34     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 35         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 36  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 37  bad berry bunny           ["flour","blueberries","sugar","butter"]
# 38     orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 39      minty miami          ["flour","mint extract","sugar","butter"]
# 40        chocolate       ["flour","chocolate chips","sugar","butter"]
# 41     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 42         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 43  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 44  bad berry bunny           ["flour","blueberries","sugar","butter"]
# 45     orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 46      minty miami          ["flour","mint extract","sugar","butter"]
# 47        chocolate       ["flour","chocolate chips","sugar","butter"]
# 48     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 49         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 50  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 51  bad berry bunny           ["flour","blueberries","sugar","butter"]
# 52     orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 53      minty miami          ["flour","mint extract","sugar","butter"]
# 54        chocolate       ["flour","chocolate chips","sugar","butter"]
# 55     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
#
#     calories  radius  cost_to_make
# 0        170   3.102          0.67
# 1        224   4.069          1.04
# 2        198   3.780          1.07
# 3        191   4.148          1.39
# 4        162   3.241          1.15
# 5        204   3.964          0.84
# 6        243   3.684          1.17
# 8        216   3.848          1.28
# 9        211   3.940          0.76
# 10       183   3.874          1.07
# 11       159   3.429          2.09
# 12       175   3.766          0.77
# 13       209   3.182          1.53
# 14       167   3.548          1.86
# 15       236   4.043          1.29
# 16       202   4.289          1.23
# 17       184   2.982          2.01
# 18       156   3.765          1.63
# 22       219   4.346          1.18
# 23       204   4.667          1.40
# 24       198   3.448          0.68
# 25       178   2.952          0.84
# 27       187   3.257          0.69
# 28       211   4.152          1.72
# 29       193   3.172          0.97
# 30       182   4.166          1.11
# 31       162   3.498          1.18
# 32       183   3.946          1.05
# 34       176   4.110          2.27
# 35       205   3.776          0.96
# 36       203   4.272          1.94
# 37       213   4.007          1.34
# 38       183   3.627          1.41
# 39       174   4.388          0.64
# 40       240   4.212          0.97
# 41       195   4.562          0.62
# 42       220   3.855          2.21
# 43       193   3.661          1.59
# 44       184   3.974          0.77
# 45       159   3.462          1.01
# 46       205   4.218          0.75
# 47       229   4.217          1.19
# 48       165   4.123          2.00
# 49       208   3.583          1.42
# 50       203   4.112          0.91
# 51       193   3.791          1.43
# 52       186   4.573          1.06
# 53       209   3.992          0.97
# 54       206   4.328          1.34
# 55       189   3.179          0.72

# %% [markdown]
# To also make sure we removed null values, we can check the number of null values in each column using the `isnull()` function.

# %%
#TODO: use the isnull method to make sure your data is clean
cookies["cost_to_make"].isnull().values.any()
# Out:
# False

# %% [markdown]
# ### Parsing the data
# Now that we have the data, we could parse it to get the information we want. For example, we can check what types of cookies were made by using the `unique()` function on the `cookie` column.

# %%
#TODO: see what cookies are in the dataset
cookies["cookie"].unique()
# Out:
# array(['laddoo lemon', 'nevadito', 'red velvet rauw', 'bad berry bunny',
#        'orange ozuna', 'minty miami', 'chocolate'], dtype=object)

# %% [markdown]
# We can also check the number of cookies made by using the `value_counts()` function on the `cookie` column.

# %%
#TODO: use value_counts() to see how many 
# cookies of each type there are
cookies["cookie"].value_counts()
# Out:
# red velvet rauw    17
# orange ozuna       16
# nevadito           15
# bad berry bunny    15
# minty miami        15
# laddoo lemon       13
# chocolate          12
# Name: cookie, dtype: int64

# %% [markdown]
# Or maybe we don't like how long the names of the cookies are, so we can shorten them by using the `replace()` function on the `cookie` column.
#
# For example, let's try changing `"bad berry bunny"` to `"bbb"`.

# %%
#TODO: change bad berry bunny data elements to "bbb"
cookies["cookie"] = cookies["cookie"].replace({"bad berry bunny": "bbb"})
cookies.head(50)
# Out:
#              cookie                                        ingredients  \
# 0      laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 1          nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 2   red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 3               bbb           ["flour","blueberries","sugar","butter"]
# 4      orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 5       minty miami          ["flour","mint extract","sugar","butter"]
# 6         chocolate       ["flour","chocolate chips","sugar","butter"]
# 8          nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 9   red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 10              bbb           ["flour","blueberries","sugar","butter"]
# 11     orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 12      minty miami          ["flour","mint extract","sugar","butter"]
# 13        chocolate       ["flour","chocolate chips","sugar","butter"]
# 14     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 15         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 16  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 17              bbb           ["flour","blueberries","sugar","butter"]
# 18     orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 22         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 23  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 24     orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 25      minty miami          ["flour","mint extract","sugar","butter"]
# 27     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 28         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 29  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 30              bbb           ["flour","blueberries","sugar","butter"]
# 31     orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 32      minty miami          ["flour","mint extract","sugar","butter"]
# 34     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 35         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 36  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 37              bbb           ["flour","blueberries","sugar","butter"]
# 38     orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 39      minty miami          ["flour","mint extract","sugar","butter"]
# 40        chocolate       ["flour","chocolate chips","sugar","butter"]
# 41     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 42         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 43  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 44              bbb           ["flour","blueberries","sugar","butter"]
# 45     orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 46      minty miami          ["flour","mint extract","sugar","butter"]
# 47        chocolate       ["flour","chocolate chips","sugar","butter"]
# 48     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 49         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 50  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 51              bbb           ["flour","blueberries","sugar","butter"]
# 52     orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 53      minty miami          ["flour","mint extract","sugar","butter"]
# 54        chocolate       ["flour","chocolate chips","sugar","butter"]
# 55     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
#
#     calories  radius  cost_to_make
# 0        170   3.102          0.67
# 1        224   4.069          1.04
# 2        198   3.780          1.07
# 3        191   4.148          1.39
# 4        162   3.241          1.15
# 5        204   3.964          0.84
# 6        243   3.684          1.17
# 8        216   3.848          1.28
# 9        211   3.940          0.76
# 10       183   3.874          1.07
# 11       159   3.429          2.09
# 12       175   3.766          0.77
# 13       209   3.182          1.53
# 14       167   3.548          1.86
# 15       236   4.043          1.29
# 16       202   4.289          1.23
# 17       184   2.982          2.01
# 18       156   3.765          1.63
# 22       219   4.346          1.18
# 23       204   4.667          1.40
# 24       198   3.448          0.68
# 25       178   2.952          0.84
# 27       187   3.257          0.69
# 28       211   4.152          1.72
# 29       193   3.172          0.97
# 30       182   4.166          1.11
# 31       162   3.498          1.18
# 32       183   3.946          1.05
# 34       176   4.110          2.27
# 35       205   3.776          0.96
# 36       203   4.272          1.94
# 37       213   4.007          1.34
# 38       183   3.627          1.41
# 39       174   4.388          0.64
# 40       240   4.212          0.97
# 41       195   4.562          0.62
# 42       220   3.855          2.21
# 43       193   3.661          1.59
# 44       184   3.974          0.77
# 45       159   3.462          1.01
# 46       205   4.218          0.75
# 47       229   4.217          1.19
# 48       165   4.123          2.00
# 49       208   3.583          1.42
# 50       203   4.112          0.91
# 51       193   3.791          1.43
# 52       186   4.573          1.06
# 53       209   3.992          0.97
# 54       206   4.328          1.34
# 55       189   3.179          0.72

# %% [markdown]
# We may even like the original names better, but we may want to get rid of the spaces. For example, we can change `"orange ozuna"` to `"orange_ozuna"`. Here, we will use the `str.replace()` function.

# %%
#TODO: adjust orange ozuna as described
cookies["cookie"] = cookies["cookie"].str.replace(" ", "_", regex=False)
cookies.head(50)
# Out:
#              cookie                                        ingredients  \
# 0      laddoo_lemon             ["flour","lemon juice","sugar","ghee"]
# 1          nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 2   red_velvet_rauw  ["flour","cocoa powder","butter","red food col...
# 3               bbb           ["flour","blueberries","sugar","butter"]
# 4      orange_ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 5       minty_miami          ["flour","mint extract","sugar","butter"]
# 6         chocolate       ["flour","chocolate chips","sugar","butter"]
# 8          nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 9   red_velvet_rauw  ["flour","cocoa powder","butter","red food col...
# 10              bbb           ["flour","blueberries","sugar","butter"]
# 11     orange_ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 12      minty_miami          ["flour","mint extract","sugar","butter"]
# 13        chocolate       ["flour","chocolate chips","sugar","butter"]
# 14     laddoo_lemon             ["flour","lemon juice","sugar","ghee"]
# 15         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 16  red_velvet_rauw  ["flour","cocoa powder","butter","red food col...
# 17              bbb           ["flour","blueberries","sugar","butter"]
# 18     orange_ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 22         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 23  red_velvet_rauw  ["flour","cocoa powder","butter","red food col...
# 24     orange_ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 25      minty_miami          ["flour","mint extract","sugar","butter"]
# 27     laddoo_lemon             ["flour","lemon juice","sugar","ghee"]
# 28         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 29  red_velvet_rauw  ["flour","cocoa powder","butter","red food col...
# 30              bbb           ["flour","blueberries","sugar","butter"]
# 31     orange_ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 32      minty_miami          ["flour","mint extract","sugar","butter"]
# 34     laddoo_lemon             ["flour","lemon juice","sugar","ghee"]
# 35         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 36  red_velvet_rauw  ["flour","cocoa powder","butter","red food col...
# 37              bbb           ["flour","blueberries","sugar","butter"]
# 38     orange_ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 39      minty_miami          ["flour","mint extract","sugar","butter"]
# 40        chocolate       ["flour","chocolate chips","sugar","butter"]
# 41     laddoo_lemon             ["flour","lemon juice","sugar","ghee"]
# 42         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 43  red_velvet_rauw  ["flour","cocoa powder","butter","red food col...
# 44              bbb           ["flour","blueberries","sugar","butter"]
# 45     orange_ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 46      minty_miami          ["flour","mint extract","sugar","butter"]
# 47        chocolate       ["flour","chocolate chips","sugar","butter"]
# 48     laddoo_lemon             ["flour","lemon juice","sugar","ghee"]
# 49         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 50  red_velvet_rauw  ["flour","cocoa powder","butter","red food col...
# 51              bbb           ["flour","blueberries","sugar","butter"]
# 52     orange_ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 53      minty_miami          ["flour","mint extract","sugar","butter"]
# 54        chocolate       ["flour","chocolate chips","sugar","butter"]
# 55     laddoo_lemon             ["flour","lemon juice","sugar","ghee"]
#
#     calories  radius  cost_to_make
# 0        170   3.102          0.67
# 1        224   4.069          1.04
# 2        198   3.780          1.07
# 3        191   4.148          1.39
# 4        162   3.241          1.15
# 5        204   3.964          0.84
# 6        243   3.684          1.17
# 8        216   3.848          1.28
# 9        211   3.940          0.76
# 10       183   3.874          1.07
# 11       159   3.429          2.09
# 12       175   3.766          0.77
# 13       209   3.182          1.53
# 14       167   3.548          1.86
# 15       236   4.043          1.29
# 16       202   4.289          1.23
# 17       184   2.982          2.01
# 18       156   3.765          1.63
# 22       219   4.346          1.18
# 23       204   4.667          1.40
# 24       198   3.448          0.68
# 25       178   2.952          0.84
# 27       187   3.257          0.69
# 28       211   4.152          1.72
# 29       193   3.172          0.97
# 30       182   4.166          1.11
# 31       162   3.498          1.18
# 32       183   3.946          1.05
# 34       176   4.110          2.27
# 35       205   3.776          0.96
# 36       203   4.272          1.94
# 37       213   4.007          1.34
# 38       183   3.627          1.41
# 39       174   4.388          0.64
# 40       240   4.212          0.97
# 41       195   4.562          0.62
# 42       220   3.855          2.21
# 43       193   3.661          1.59
# 44       184   3.974          0.77
# 45       159   3.462          1.01
# 46       205   4.218          0.75
# 47       229   4.217          1.19
# 48       165   4.123          2.00
# 49       208   3.583          1.42
# 50       203   4.112          0.91
# 51       193   3.791          1.43
# 52       186   4.573          1.06
# 53       209   3.992          0.97
# 54       206   4.328          1.34
# 55       189   3.179          0.72

# %% [markdown]
# We may even just want to keep the first word of the cookie name. For example, we can change `"orange_ozuna"` to `"orange"`.

# %%
#TODO: adjust all cookies so only the first word
# is used as the cookie name
def extract_first(string):
    out = ""
    for i in string:
        if i == '_':
            break
        out += i
    return out

cookies["cookie"] = cookies["cookie"].apply(lambda x : extract_first(x))
cookies.head(50)
# Out:
#        cookie                                        ingredients  calories  \
# 0      laddoo             ["flour","lemon juice","sugar","ghee"]       170
# 1    nevadito  ["flour","chocolate chips","milk","vanilla ext...       224
# 2         red  ["flour","cocoa powder","butter","red food col...       198
# 3         bbb           ["flour","blueberries","sugar","butter"]       191
# 4      orange   ["flour","orange juice","sugar","vegetable oil"]       162
# 5       minty          ["flour","mint extract","sugar","butter"]       204
# 6   chocolate       ["flour","chocolate chips","sugar","butter"]       243
# 8    nevadito  ["flour","chocolate chips","milk","vanilla ext...       216
# 9         red  ["flour","cocoa powder","butter","red food col...       211
# 10        bbb           ["flour","blueberries","sugar","butter"]       183
# 11     orange   ["flour","orange juice","sugar","vegetable oil"]       159
# 12      minty          ["flour","mint extract","sugar","butter"]       175
# 13  chocolate       ["flour","chocolate chips","sugar","butter"]       209
# 14     laddoo             ["flour","lemon juice","sugar","ghee"]       167
# 15   nevadito  ["flour","chocolate chips","milk","vanilla ext...       236
# 16        red  ["flour","cocoa powder","butter","red food col...       202
# 17        bbb           ["flour","blueberries","sugar","butter"]       184
# 18     orange   ["flour","orange juice","sugar","vegetable oil"]       156
# 22   nevadito  ["flour","chocolate chips","milk","vanilla ext...       219
# 23        red  ["flour","cocoa powder","butter","red food col...       204
# 24     orange   ["flour","orange juice","sugar","vegetable oil"]       198
# 25      minty          ["flour","mint extract","sugar","butter"]       178
# 27     laddoo             ["flour","lemon juice","sugar","ghee"]       187
# 28   nevadito  ["flour","chocolate chips","milk","vanilla ext...       211
# 29        red  ["flour","cocoa powder","butter","red food col...       193
# 30        bbb           ["flour","blueberries","sugar","butter"]       182
# 31     orange   ["flour","orange juice","sugar","vegetable oil"]       162
# 32      minty          ["flour","mint extract","sugar","butter"]       183
# 34     laddoo             ["flour","lemon juice","sugar","ghee"]       176
# 35   nevadito  ["flour","chocolate chips","milk","vanilla ext...       205
# 36        red  ["flour","cocoa powder","butter","red food col...       203
# 37        bbb           ["flour","blueberries","sugar","butter"]       213
# 38     orange   ["flour","orange juice","sugar","vegetable oil"]       183
# 39      minty          ["flour","mint extract","sugar","butter"]       174
# 40  chocolate       ["flour","chocolate chips","sugar","butter"]       240
# 41     laddoo             ["flour","lemon juice","sugar","ghee"]       195
# 42   nevadito  ["flour","chocolate chips","milk","vanilla ext...       220
# 43        red  ["flour","cocoa powder","butter","red food col...       193
# 44        bbb           ["flour","blueberries","sugar","butter"]       184
# 45     orange   ["flour","orange juice","sugar","vegetable oil"]       159
# 46      minty          ["flour","mint extract","sugar","butter"]       205
# 47  chocolate       ["flour","chocolate chips","sugar","butter"]       229
# 48     laddoo             ["flour","lemon juice","sugar","ghee"]       165
# 49   nevadito  ["flour","chocolate chips","milk","vanilla ext...       208
# 50        red  ["flour","cocoa powder","butter","red food col...       203
# 51        bbb           ["flour","blueberries","sugar","butter"]       193
# 52     orange   ["flour","orange juice","sugar","vegetable oil"]       186
# 53      minty          ["flour","mint extract","sugar","butter"]       209
# 54  chocolate       ["flour","chocolate chips","sugar","butter"]       206
# 55     laddoo             ["flour","lemon juice","sugar","ghee"]       189
#
#     radius  cost_to_make
# 0    3.102          0.67
# 1    4.069          1.04
# 2    3.780          1.07
# 3    4.148          1.39
# 4    3.241          1.15
# 5    3.964          0.84
# 6    3.684          1.17
# 8    3.848          1.28
# 9    3.940          0.76
# 10   3.874          1.07
# 11   3.429          2.09
# 12   3.766          0.77
# 13   3.182          1.53
# 14   3.548          1.86
# 15   4.043          1.29
# 16   4.289          1.23
# 17   2.982          2.01
# 18   3.765          1.63
# 22   4.346          1.18
# 23   4.667          1.40
# 24   3.448          0.68
# 25   2.952          0.84
# 27   3.257          0.69
# 28   4.152          1.72
# 29   3.172          0.97
# 30   4.166          1.11
# 31   3.498          1.18
# 32   3.946          1.05
# 34   4.110          2.27
# 35   3.776          0.96
# 36   4.272          1.94
# 37   4.007          1.34
# 38   3.627          1.41
# 39   4.388          0.64
# 40   4.212          0.97
# 41   4.562          0.62
# 42   3.855          2.21
# 43   3.661          1.59
# 44   3.974          0.77
# 45   3.462          1.01
# 46   4.218          0.75
# 47   4.217          1.19
# 48   4.123          2.00
# 49   3.583          1.42
# 50   4.112          0.91
# 51   3.791          1.43
# 52   4.573          1.06
# 53   3.992          0.97
# 54   4.328          1.34
# 55   3.179          0.72

# %% [markdown]
# Another thing that may come to mind is that maybe getting flour could cost more money due to inflation, so we have to adjust our `cost_to_make` values, similar to how in the homework there is a `price_adjustments`. We can do this by using the `apply()` function on the `cost_to_make` column.

# %%
#Don't edit this method
def adjust_cost(cost):
    return cost + 0.5

#TODO: use apply() to adjust the cost_to_make column.
cookies["cost_to_make"] = cookies["cost_to_make"].apply(lambda x : adjust_cost(x))
cookies.head(50)
# Out:
#        cookie                                        ingredients  calories  \
# 0      laddoo             ["flour","lemon juice","sugar","ghee"]       170
# 1    nevadito  ["flour","chocolate chips","milk","vanilla ext...       224
# 2         red  ["flour","cocoa powder","butter","red food col...       198
# 3         bbb           ["flour","blueberries","sugar","butter"]       191
# 4      orange   ["flour","orange juice","sugar","vegetable oil"]       162
# 5       minty          ["flour","mint extract","sugar","butter"]       204
# 6   chocolate       ["flour","chocolate chips","sugar","butter"]       243
# 8    nevadito  ["flour","chocolate chips","milk","vanilla ext...       216
# 9         red  ["flour","cocoa powder","butter","red food col...       211
# 10        bbb           ["flour","blueberries","sugar","butter"]       183
# 11     orange   ["flour","orange juice","sugar","vegetable oil"]       159
# 12      minty          ["flour","mint extract","sugar","butter"]       175
# 13  chocolate       ["flour","chocolate chips","sugar","butter"]       209
# 14     laddoo             ["flour","lemon juice","sugar","ghee"]       167
# 15   nevadito  ["flour","chocolate chips","milk","vanilla ext...       236
# 16        red  ["flour","cocoa powder","butter","red food col...       202
# 17        bbb           ["flour","blueberries","sugar","butter"]       184
# 18     orange   ["flour","orange juice","sugar","vegetable oil"]       156
# 22   nevadito  ["flour","chocolate chips","milk","vanilla ext...       219
# 23        red  ["flour","cocoa powder","butter","red food col...       204
# 24     orange   ["flour","orange juice","sugar","vegetable oil"]       198
# 25      minty          ["flour","mint extract","sugar","butter"]       178
# 27     laddoo             ["flour","lemon juice","sugar","ghee"]       187
# 28   nevadito  ["flour","chocolate chips","milk","vanilla ext...       211
# 29        red  ["flour","cocoa powder","butter","red food col...       193
# 30        bbb           ["flour","blueberries","sugar","butter"]       182
# 31     orange   ["flour","orange juice","sugar","vegetable oil"]       162
# 32      minty          ["flour","mint extract","sugar","butter"]       183
# 34     laddoo             ["flour","lemon juice","sugar","ghee"]       176
# 35   nevadito  ["flour","chocolate chips","milk","vanilla ext...       205
# 36        red  ["flour","cocoa powder","butter","red food col...       203
# 37        bbb           ["flour","blueberries","sugar","butter"]       213
# 38     orange   ["flour","orange juice","sugar","vegetable oil"]       183
# 39      minty          ["flour","mint extract","sugar","butter"]       174
# 40  chocolate       ["flour","chocolate chips","sugar","butter"]       240
# 41     laddoo             ["flour","lemon juice","sugar","ghee"]       195
# 42   nevadito  ["flour","chocolate chips","milk","vanilla ext...       220
# 43        red  ["flour","cocoa powder","butter","red food col...       193
# 44        bbb           ["flour","blueberries","sugar","butter"]       184
# 45     orange   ["flour","orange juice","sugar","vegetable oil"]       159
# 46      minty          ["flour","mint extract","sugar","butter"]       205
# 47  chocolate       ["flour","chocolate chips","sugar","butter"]       229
# 48     laddoo             ["flour","lemon juice","sugar","ghee"]       165
# 49   nevadito  ["flour","chocolate chips","milk","vanilla ext...       208
# 50        red  ["flour","cocoa powder","butter","red food col...       203
# 51        bbb           ["flour","blueberries","sugar","butter"]       193
# 52     orange   ["flour","orange juice","sugar","vegetable oil"]       186
# 53      minty          ["flour","mint extract","sugar","butter"]       209
# 54  chocolate       ["flour","chocolate chips","sugar","butter"]       206
# 55     laddoo             ["flour","lemon juice","sugar","ghee"]       189
#
#     radius  cost_to_make
# 0    3.102          1.17
# 1    4.069          1.54
# 2    3.780          1.57
# 3    4.148          1.89
# 4    3.241          1.65
# 5    3.964          1.34
# 6    3.684          1.67
# 8    3.848          1.78
# 9    3.940          1.26
# 10   3.874          1.57
# 11   3.429          2.59
# 12   3.766          1.27
# 13   3.182          2.03
# 14   3.548          2.36
# 15   4.043          1.79
# 16   4.289          1.73
# 17   2.982          2.51
# 18   3.765          2.13
# 22   4.346          1.68
# 23   4.667          1.90
# 24   3.448          1.18
# 25   2.952          1.34
# 27   3.257          1.19
# 28   4.152          2.22
# 29   3.172          1.47
# 30   4.166          1.61
# 31   3.498          1.68
# 32   3.946          1.55
# 34   4.110          2.77
# 35   3.776          1.46
# 36   4.272          2.44
# 37   4.007          1.84
# 38   3.627          1.91
# 39   4.388          1.14
# 40   4.212          1.47
# 41   4.562          1.12
# 42   3.855          2.71
# 43   3.661          2.09
# 44   3.974          1.27
# 45   3.462          1.51
# 46   4.218          1.25
# 47   4.217          1.69
# 48   4.123          2.50
# 49   3.583          1.92
# 50   4.112          1.41
# 51   3.791          1.93
# 52   4.573          1.56
# 53   3.992          1.47
# 54   4.328          1.84
# 55   3.179          1.22

# %% [markdown]
# And we can do a lot more things! We will see these concepts be used in the next homework assignment, along with a couple new ones to show you how powerful Pandas is.

# %% [markdown]
# ### More complicated operations: Grouping, Filtering, Aggregating

# %% [markdown]
# We may also want to group data by certain attributes. This can be done by using `groupby()`. This method takes in a column name, and groups the data by the values in that column. For example, we can group the data by the `cookie` column.

# %%
#TODO: group by cookie type
grouped = cookies.groupby(["cookie"]).mean()
grouped.head()
# Out:
# C:\Users\bluel\AppData\Local\Temp\ipykernel_1352\1595158875.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped = cookies.groupby(["cookie"]).mean()
#              calories    radius  cost_to_make
# cookie
# bbb        188.466667  3.914867      1.652667
# chocolate  221.416667  4.062833      1.710833
# laddoo     174.384615  3.849000      1.803077
# minty      186.266667  3.714467      1.438000
# nevadito   222.400000  3.959000      1.864667

# %% [markdown]
# We can also group by multiple columns. For example, we can group the data by the `cookie` and `ingredients` columns.

# %%
#TODO: group by cookie type and ingredients
grouped2 = cookies.groupby(["cookie", "ingredients"]).mean()
grouped2.head()
# Out:
#                                                                 calories  \
# cookie    ingredients
# bbb       ["flour","blueberries","sugar","butter"]            188.466667
# chocolate ["flour","chocolate chips","sugar","butter"]        221.416667
# laddoo    ["flour","lemon juice","sugar","ghee"]              174.384615
# minty     ["flour","mint extract","sugar","butter"]           186.266667
# nevadito  ["flour","chocolate chips","milk","vanilla extr...  222.400000
#
#                                                                 radius  \
# cookie    ingredients
# bbb       ["flour","blueberries","sugar","butter"]            3.914867
# chocolate ["flour","chocolate chips","sugar","butter"]        4.062833
# laddoo    ["flour","lemon juice","sugar","ghee"]              3.849000
# minty     ["flour","mint extract","sugar","butter"]           3.714467
# nevadito  ["flour","chocolate chips","milk","vanilla extr...  3.959000
#
#                                                               cost_to_make
# cookie    ingredients
# bbb       ["flour","blueberries","sugar","butter"]                1.652667
# chocolate ["flour","chocolate chips","sugar","butter"]            1.710833
# laddoo    ["flour","lemon juice","sugar","ghee"]                  1.803077
# minty     ["flour","mint extract","sugar","butter"]               1.438000
# nevadito  ["flour","chocolate chips","milk","vanilla extr...      1.864667

# %% [markdown]
# We may also want to filter the data. For example, we can filter the data to only show the cookies that have a radius greater than 4.3 cm. We can do this by indexing the DataFrame with a boolean expression.

# %%
#TODO: filter using the boolean expression
filtered = cookies[cookies["radius"] > 4.3]
filtered.head(50)
# Out:
#         cookie                                        ingredients  calories  \
# 22    nevadito  ["flour","chocolate chips","milk","vanilla ext...       219
# 23         red  ["flour","cocoa powder","butter","red food col...       204
# 39       minty          ["flour","mint extract","sugar","butter"]       174
# 41      laddoo             ["flour","lemon juice","sugar","ghee"]       195
# 52      orange   ["flour","orange juice","sugar","vegetable oil"]       186
# 54   chocolate       ["flour","chocolate chips","sugar","butter"]       206
# 64         red  ["flour","cocoa powder","butter","red food col...       196
# 68         red  ["flour","cocoa powder","butter","red food col...       206
# 72   chocolate       ["flour","chocolate chips","sugar","butter"]       197
# 79   chocolate       ["flour","chocolate chips","sugar","butter"]       199
# 80      laddoo             ["flour","lemon juice","sugar","ghee"]       167
# 89         red  ["flour","cocoa powder","butter","red food col...       191
# 93      laddoo             ["flour","lemon juice","sugar","ghee"]       178
# 102        red  ["flour","cocoa powder","butter","red food col...       198
#
#      radius  cost_to_make
# 22    4.346          1.68
# 23    4.667          1.90
# 39    4.388          1.14
# 41    4.562          1.12
# 52    4.573          1.56
# 54    4.328          1.84
# 64    4.425          1.37
# 68    4.319          1.74
# 72    4.461          2.17
# 79    4.474          1.64
# 80    4.401          1.74
# 89    4.475          1.74
# 93    4.519          1.91
# 102   4.930          1.55

# %% [markdown]
# We may even want to use `groupby()` and filter idea together! For example, we can filter the data to only show the cookies that have a radius greater than 4.3 cm, and group the data by the `cookie` column.

# %%
#TODO: filter the data using the boolean expression
# then group by cookie column
combined = cookies[cookies["radius"] > 4.3].groupby(["cookie"]).mean()
combined.head(50)
# Out:
# C:\Users\bluel\AppData\Local\Temp\ipykernel_1352\4245075508.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   combined = cookies[cookies["radius"] > 4.3].groupby(["cookie"]).mean()
#              calories  radius  cost_to_make
# cookie
# chocolate  200.666667  4.4210      1.883333
# laddoo     180.000000  4.4940      1.590000
# minty      174.000000  4.3880      1.140000
# nevadito   219.000000  4.3460      1.680000
# orange     186.000000  4.5730      1.560000
# red        199.000000  4.5632      1.660000

# %% [markdown]
# We may also want to aggregate the data. For example, we can aggregate the data by looking at the ratio of calories to radius. We can do this by using indexing and the `apply()` function.

# %%
#TODO: add a column to the dataframe that is the
# calories per radius
cookies["cals_to_rad"] = cookies["calories"] / cookies["radius"]
cookies.head()
# Out:
#      cookie                                        ingredients  calories  \
# 0    laddoo             ["flour","lemon juice","sugar","ghee"]       170
# 1  nevadito  ["flour","chocolate chips","milk","vanilla ext...       224
# 2       red  ["flour","cocoa powder","butter","red food col...       198
# 3       bbb           ["flour","blueberries","sugar","butter"]       191
# 4    orange   ["flour","orange juice","sugar","vegetable oil"]       162
#
#    radius  cost_to_make  cals_to_rad
# 0   3.102          1.17    54.803353
# 1   4.069          1.54    55.050381
# 2   3.780          1.57    52.380952
# 3   4.148          1.89    46.046287
# 4   3.241          1.65    49.984573

# %% [markdown]
# Or we can just get rid of this column if we find it useless. We can do this by using the `drop()` function or indexing.

# %%
#TODO: drop the created column
cookies = cookies.drop(["cals_to_rad"], axis=1)
cookies.head()
# Out:
#      cookie                                        ingredients  calories  \
# 0    laddoo             ["flour","lemon juice","sugar","ghee"]       170
# 1  nevadito  ["flour","chocolate chips","milk","vanilla ext...       224
# 2       red  ["flour","cocoa powder","butter","red food col...       198
# 3       bbb           ["flour","blueberries","sugar","butter"]       191
# 4    orange   ["flour","orange juice","sugar","vegetable oil"]       162
#
#    radius  cost_to_make
# 0   3.102          1.17
# 1   4.069          1.54
# 2   3.780          1.57
# 3   4.148          1.89
# 4   3.241          1.65

# %% [markdown]
# ### Visualizing the data

# %% [markdown]
# We can also visualize the data. For example, we can visualize the data by plotting the radius of the cookies against the cost to make the cookies. We can do this by using the `plot()` function.

# %%
#TODO: plot the radius (x) versus cost to make (y)
cookies.plot(x="radius", y="cost_to_make", kind="scatter")
# Out:
# <AxesSubplot: xlabel='radius', ylabel='cost_to_make'>

# %% [markdown]
# We may even want to get more specific and visualize the shape of a distribution of the `laddoo lemon`'s radius by making a boxplot. We can also do this by using the `plot()` function.

# %%
#TODO: add the described boxplot
cookies[cookies["cookie"] == "laddoo"].plot(y="radius", kind="box")
# Out:
# <AxesSubplot: >

# %% [markdown]
# Alternatively, we can create a histogram to visualize the distribution of the `laddoo lemon`'s radius. We can also do this by using the `plot()` function.

# %%
#TODO: add the described histogram
cookies[cookies["cookie"] == "laddoo"].plot(y="radius", kind="hist")
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# Things can get more complicated too. Maybe we want to analyze the behaviors of `bad berry bunny` and `laddoo lemon`'s radius using a boxplot. But this time, let's try it using the alternative `boxplot()` function. For practice, try doing it with `plot()` too!

# %%
#TODO: analyze the two cookie's radius in a boxplot
cookies[(cookies["cookie"] == "bbb") | (cookies["cookie"] == "laddoo")].boxplot(column=["radius"], by="cookie")
# Out:
# <AxesSubplot: title={'center': 'radius'}, xlabel='cookie'>

# %% [markdown]
# ### Practice Problems
# Now that you have learned some of Pandas' capabilities, let's try some practice problems! **This is the part that will be checked when you submit it!**

# %% [markdown]
# #### Problem 1
# How many cookies were made? (Hint: use the `shape` attribute)
#
# * 103 (after filtering out ones without a cost_to_make value)

# %%
cookies.shape
# Out:
# (103, 5)

# %% [markdown]
# #### Problem 2
# Add a column to the DataFrame that has the value `True` if the cookie has a radius greater than 4 cm, and `False` otherwise. (Hint: use the `apply()` function)

# %%
#Add your code here
cookies["rad_gt_4"] = (cookies["radius"] > 4)
cookies.head()
# Out:
#      cookie                                        ingredients  calories  \
# 0    laddoo             ["flour","lemon juice","sugar","ghee"]       170
# 1  nevadito  ["flour","chocolate chips","milk","vanilla ext...       224
# 2       red  ["flour","cocoa powder","butter","red food col...       198
# 3       bbb           ["flour","blueberries","sugar","butter"]       191
# 4    orange   ["flour","orange juice","sugar","vegetable oil"]       162
#
#    radius  cost_to_make  rad_gt_4
# 0   3.102          1.17     False
# 1   4.069          1.54      True
# 2   3.780          1.57     False
# 3   4.148          1.89      True
# 4   3.241          1.65     False

# %% [markdown]
# #### Problem 3
#
# Group the data by the `cookie` column, and find the average radius of each cookie. (Hint: use the `groupby()` and `transform()` function). Add this column to the DataFrame.

# %%
#Add your code here
group_rad = cookies.groupby("cookie")["radius"].transform("mean")
cookies["mean_rad"] = group_rad
cookies.head(50)
# Out:
#        cookie                                        ingredients  calories  \
# 0      laddoo             ["flour","lemon juice","sugar","ghee"]       170
# 1    nevadito  ["flour","chocolate chips","milk","vanilla ext...       224
# 2         red  ["flour","cocoa powder","butter","red food col...       198
# 3         bbb           ["flour","blueberries","sugar","butter"]       191
# 4      orange   ["flour","orange juice","sugar","vegetable oil"]       162
# 5       minty          ["flour","mint extract","sugar","butter"]       204
# 6   chocolate       ["flour","chocolate chips","sugar","butter"]       243
# 8    nevadito  ["flour","chocolate chips","milk","vanilla ext...       216
# 9         red  ["flour","cocoa powder","butter","red food col...       211
# 10        bbb           ["flour","blueberries","sugar","butter"]       183
# 11     orange   ["flour","orange juice","sugar","vegetable oil"]       159
# 12      minty          ["flour","mint extract","sugar","butter"]       175
# 13  chocolate       ["flour","chocolate chips","sugar","butter"]       209
# 14     laddoo             ["flour","lemon juice","sugar","ghee"]       167
# 15   nevadito  ["flour","chocolate chips","milk","vanilla ext...       236
# 16        red  ["flour","cocoa powder","butter","red food col...       202
# 17        bbb           ["flour","blueberries","sugar","butter"]       184
# 18     orange   ["flour","orange juice","sugar","vegetable oil"]       156
# 22   nevadito  ["flour","chocolate chips","milk","vanilla ext...       219
# 23        red  ["flour","cocoa powder","butter","red food col...       204
# 24     orange   ["flour","orange juice","sugar","vegetable oil"]       198
# 25      minty          ["flour","mint extract","sugar","butter"]       178
# 27     laddoo             ["flour","lemon juice","sugar","ghee"]       187
# 28   nevadito  ["flour","chocolate chips","milk","vanilla ext...       211
# 29        red  ["flour","cocoa powder","butter","red food col...       193
# 30        bbb           ["flour","blueberries","sugar","butter"]       182
# 31     orange   ["flour","orange juice","sugar","vegetable oil"]       162
# 32      minty          ["flour","mint extract","sugar","butter"]       183
# 34     laddoo             ["flour","lemon juice","sugar","ghee"]       176
# 35   nevadito  ["flour","chocolate chips","milk","vanilla ext...       205
# 36        red  ["flour","cocoa powder","butter","red food col...       203
# 37        bbb           ["flour","blueberries","sugar","butter"]       213
# 38     orange   ["flour","orange juice","sugar","vegetable oil"]       183
# 39      minty          ["flour","mint extract","sugar","butter"]       174
# 40  chocolate       ["flour","chocolate chips","sugar","butter"]       240
# 41     laddoo             ["flour","lemon juice","sugar","ghee"]       195
# 42   nevadito  ["flour","chocolate chips","milk","vanilla ext...       220
# 43        red  ["flour","cocoa powder","butter","red food col...       193
# 44        bbb           ["flour","blueberries","sugar","butter"]       184
# 45     orange   ["flour","orange juice","sugar","vegetable oil"]       159
# 46      minty          ["flour","mint extract","sugar","butter"]       205
# 47  chocolate       ["flour","chocolate chips","sugar","butter"]       229
# 48     laddoo             ["flour","lemon juice","sugar","ghee"]       165
# 49   nevadito  ["flour","chocolate chips","milk","vanilla ext...       208
# 50        red  ["flour","cocoa powder","butter","red food col...       203
# 51        bbb           ["flour","blueberries","sugar","butter"]       193
# 52     orange   ["flour","orange juice","sugar","vegetable oil"]       186
# 53      minty          ["flour","mint extract","sugar","butter"]       209
# 54  chocolate       ["flour","chocolate chips","sugar","butter"]       206
# 55     laddoo             ["flour","lemon juice","sugar","ghee"]       189
#
#     radius  cost_to_make  rad_gt_4  mean_rad
# 0    3.102          1.17     False  3.849000
# 1    4.069          1.54      True  3.959000
# 2    3.780          1.57     False  4.106471
# 3    4.148          1.89      True  3.914867
# 4    3.241          1.65     False  3.506125
# 5    3.964          1.34     False  3.714467
# 6    3.684          1.67     False  4.062833
# 8    3.848          1.78     False  3.959000
# 9    3.940          1.26     False  4.106471
# 10   3.874          1.57     False  3.914867
# 11   3.429          2.59     False  3.506125
# 12   3.766          1.27     False  3.714467
# 13   3.182          2.03     False  4.062833
# 14   3.548          2.36     False  3.849000
# 15   4.043          1.79      True  3.959000
# 16   4.289          1.73      True  4.106471
# 17   2.982          2.51     False  3.914867
# 18   3.765          2.13     False  3.506125
# 22   4.346          1.68      True  3.959000
# 23   4.667          1.90      True  4.106471
# 24   3.448          1.18     False  3.506125
# 25   2.952          1.34     False  3.714467
# 27   3.257          1.19     False  3.849000
# 28   4.152          2.22      True  3.959000
# 29   3.172          1.47     False  4.106471
# 30   4.166          1.61      True  3.914867
# 31   3.498          1.68     False  3.506125
# 32   3.946          1.55     False  3.714467
# 34   4.110          2.77      True  3.849000
# 35   3.776          1.46     False  3.959000
# 36   4.272          2.44      True  4.106471
# 37   4.007          1.84      True  3.914867
# 38   3.627          1.91     False  3.506125
# 39   4.388          1.14      True  3.714467
# 40   4.212          1.47      True  4.062833
# 41   4.562          1.12      True  3.849000
# 42   3.855          2.71     False  3.959000
# 43   3.661          2.09     False  4.106471
# 44   3.974          1.27     False  3.914867
# 45   3.462          1.51     False  3.506125
# 46   4.218          1.25      True  3.714467
# 47   4.217          1.69      True  4.062833
# 48   4.123          2.50      True  3.849000
# 49   3.583          1.92     False  3.959000
# 50   4.112          1.41      True  4.106471
# 51   3.791          1.93     False  3.914867
# 52   4.573          1.56      True  3.506125
# 53   3.992          1.47     False  3.714467
# 54   4.328          1.84      True  4.062833
# 55   3.179          1.22     False  3.849000

# %% [markdown]
# #### Problem 4
# Create a new DataFrame that only contains the cookies that have the ingredient `"chocolate chips"`. (Hint: use the `str.contains()` function)

# %%
#Add your code here
choccy_chips_gang = cookies[cookies["ingredients"].str.contains("chocolate chips")]
choccy_chips_gang.head(10)
# Out:
#        cookie                                        ingredients  calories  \
# 1    nevadito  ["flour","chocolate chips","milk","vanilla ext...       224
# 6   chocolate       ["flour","chocolate chips","sugar","butter"]       243
# 8    nevadito  ["flour","chocolate chips","milk","vanilla ext...       216
# 13  chocolate       ["flour","chocolate chips","sugar","butter"]       209
# 15   nevadito  ["flour","chocolate chips","milk","vanilla ext...       236
# 22   nevadito  ["flour","chocolate chips","milk","vanilla ext...       219
# 28   nevadito  ["flour","chocolate chips","milk","vanilla ext...       211
# 35   nevadito  ["flour","chocolate chips","milk","vanilla ext...       205
# 40  chocolate       ["flour","chocolate chips","sugar","butter"]       240
# 42   nevadito  ["flour","chocolate chips","milk","vanilla ext...       220
#
#     radius  cost_to_make  rad_gt_4  mean_rad
# 1    4.069          1.54      True  3.959000
# 6    3.684          1.67     False  4.062833
# 8    3.848          1.78     False  3.959000
# 13   3.182          2.03     False  4.062833
# 15   4.043          1.79      True  3.959000
# 22   4.346          1.68      True  3.959000
# 28   4.152          2.22      True  3.959000
# 35   3.776          1.46     False  3.959000
# 40   4.212          1.47      True  4.062833
# 42   3.855          2.71     False  3.959000

# %% [markdown]
# #### Problem 5
#
# Create a boxplot of `cost_to_make` for all cookies except `chocolate` using the `boxplot()` function.

# %%
#Add your code here
cookies[cookies["cookie"] != "chocolate"].boxplot(column="cost_to_make", by="cookie")
# Out:
# <AxesSubplot: title={'center': 'cost_to_make'}, xlabel='cookie'>

# %% [markdown]
# #### Problem 6
#
# Create a histogram of the `bad berry bunny`'s calories using the `plot()` function.

# %%
#Add your code here
cookies[cookies["cookie"] == "bbb"].plot(y="calories", kind="hist")
# Out:
# <AxesSubplot: ylabel='Frequency'>
